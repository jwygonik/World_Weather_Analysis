# %%
# Create a set of 2000 random lat and lngs
#  Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
# declare each array as variable so latitudes and longitudes can be stored for later use

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#Create set of randome latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add lats and lngs to list

coordinates = list(lat_lngs)

# %%
# Get nearest city using citipy

from citipy import citipy
# import the requests library

import requests

# import api key

from config import weather_api_key

# %%
# Create list to hold the cities

cities = []

# ID the nearest city for each lat and lng combo 

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, the add to our cities list
    
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count (1500)
len(cities)
# Out:
# 738

# %%
# import dependencies
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval"     )
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | saint-pierre
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | totma
# Processing Record 6 of Set 1 | copperas cove
# Processing Record 7 of Set 1 | alausi
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | cabedelo
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | egvekinot
# Processing Record 16 of Set 1 | constantine
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | prijepolje
# Processing Record 19 of Set 1 | bonavista
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | neiafu
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | taoudenni
# Processing Record 30 of Set 1 | abaetetuba
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | luoyang
# Processing Record 34 of Set 1 | ukiah
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | kharhial
# Processing Record 37 of Set 1 | chimore
# Processing Record 38 of Set 1 | husavik
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | ayan
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | anito
# Processing Record 47 of Set 1 | san quintin
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | baoying
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | carmo
# Processing Record 5 of Set 2 | calvia
# Processing Record 6 of Set 2 | palmer
# Processing Record 7 of Set 2 | tsuruoka
# Processing Record 8 of Set 2 | maragogi
# Processing Record 9 of Set 2 | saint anthony
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | campbell river
# Processing Record 12 of Set 2 | kanye
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | male
# Processing Record 17 of Set 2 | praia
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | bagdarin
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | monze
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | chumphon
# Processing Record 32 of Set 2 | verkh-usugli
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | piquete
# Processing Record 37 of Set 2 | kaniama
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | umm kaddadah
# Processing Record 40 of Set 2 | coahuayana
# Processing Record 41 of Set 2 | timmins
# Processing Record 42 of Set 2 | orlik
# Processing Record 43 of Set 2 | champerico
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | cabo rojo
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | sao pedro
# Processing Record 48 of Set 2 | valle de allende
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | ryotsu
# Processing Record 1 of Set 3 | grand gaube
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | warri
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | fukue
# Processing Record 7 of Set 3 | buala
# Processing Record 8 of Set 3 | comodoro rivadavia
# Processing Record 9 of Set 3 | caconda
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | oranjestad
# Processing Record 12 of Set 3 | caravelas
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | monrovia
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | katete
# Processing Record 18 of Set 3 | berlevag
# Processing Record 19 of Set 3 | koumac
# Processing Record 20 of Set 3 | sao jose da coroa grande
# Processing Record 21 of Set 3 | xuddur
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | road town
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | fairbanks
# Processing Record 29 of Set 3 | ilebo
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | culfa
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | sogdiondon
# City not found. Skipping...
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | gallup
# Processing Record 37 of Set 3 | manta
# Processing Record 38 of Set 3 | soma
# Processing Record 39 of Set 3 | okha
# Processing Record 40 of Set 3 | klaksvik
# Processing Record 41 of Set 3 | cockburn town
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | saryozek
# Processing Record 49 of Set 3 | sinnamary
# Processing Record 50 of Set 3 | kapaa
# Processing Record 1 of Set 4 | beyneu
# Processing Record 2 of Set 4 | kodarma
# Processing Record 3 of Set 4 | tromso
# Processing Record 4 of Set 4 | mananjary
# Processing Record 5 of Set 4 | chany
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | urumqi
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | vanavara
# Processing Record 10 of Set 4 | sambava
# Processing Record 11 of Set 4 | saint-paul
# Processing Record 12 of Set 4 | sibolga
# Processing Record 13 of Set 4 | molango
# Processing Record 14 of Set 4 | yatou
# Processing Record 15 of Set 4 | guaymas
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | gornyy
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | amot
# Processing Record 20 of Set 4 | aykhal
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | eisiskes
# Processing Record 23 of Set 4 | mattru
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | xingyi
# Processing Record 26 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 4 | luba
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | mataura
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 4 | baiyin
# Processing Record 35 of Set 4 | price
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | san ramon
# Processing Record 38 of Set 4 | sakhon nakhon
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | bonthe
# Processing Record 41 of Set 4 | nikolsk
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | havre-saint-pierre
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 4 | belaya gora
# Processing Record 48 of Set 4 | chernyshevskiy
# Processing Record 49 of Set 4 | lorengau
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | hobart
# Processing Record 4 of Set 5 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 5 of Set 5 | rancho palos verdes
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | namatanai
# Processing Record 8 of Set 5 | jinchang
# Processing Record 9 of Set 5 | plouzane
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | flin flon
# Processing Record 12 of Set 5 | tateyama
# Processing Record 13 of Set 5 | ketchikan
# Processing Record 14 of Set 5 | vila
# Processing Record 15 of Set 5 | tuktoyaktuk
# Processing Record 16 of Set 5 | teya
# Processing Record 17 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 5 | laranjeiras do sul
# Processing Record 19 of Set 5 | mawlaik
# Processing Record 20 of Set 5 | pangkalanbuun
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | samarai
# Processing Record 23 of Set 5 | korla
# Processing Record 24 of Set 5 | fushun
# Processing Record 25 of Set 5 | kendari
# Processing Record 26 of Set 5 | iroquois falls
# Processing Record 27 of Set 5 | kodinsk
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | opobo
# City not found. Skipping...
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | amapa
# Processing Record 32 of Set 5 | maymyo
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | ponta do sol
# Processing Record 36 of Set 5 | tombouctou
# Processing Record 37 of Set 5 | karratha
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | kedrovyy
# Processing Record 40 of Set 5 | camocim
# Processing Record 41 of Set 5 | sibu
# Processing Record 42 of Set 5 | deputatskiy
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | catalao
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | uvat
# Processing Record 47 of Set 5 | bengbu
# Processing Record 48 of Set 5 | gazojak
# Processing Record 49 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | orotukan
# Processing Record 2 of Set 6 | soyo
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | misratah
# Processing Record 5 of Set 6 | tonantins
# Processing Record 6 of Set 6 | mackay
# Processing Record 7 of Set 6 | porto santo
# Processing Record 8 of Set 6 | vostok
# Processing Record 9 of Set 6 | granada
# Processing Record 10 of Set 6 | chokurdakh
# Processing Record 11 of Set 6 | padang
# Processing Record 12 of Set 6 | kinston
# Processing Record 13 of Set 6 | zhigansk
# Processing Record 14 of Set 6 | sabang
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | karasuk
# Processing Record 17 of Set 6 | visnes
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | upernavik
# Processing Record 21 of Set 6 | cayenne
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | ardakan
# Processing Record 24 of Set 6 | atherton
# Processing Record 25 of Set 6 | ishigaki
# Processing Record 26 of Set 6 | chifeng
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | norman wells
# Processing Record 29 of Set 6 | sirvintos
# Processing Record 30 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | micheweni
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | jashpurnagar
# Processing Record 34 of Set 6 | petauke
# Processing Record 35 of Set 6 | candelaria
# Processing Record 36 of Set 6 | resistencia
# Processing Record 37 of Set 6 | araouane
# Processing Record 38 of Set 6 | port macquarie
# Processing Record 39 of Set 6 | taksimo
# Processing Record 40 of Set 6 | trinidad
# Processing Record 41 of Set 6 | bahia blanca
# Processing Record 42 of Set 6 | dordrecht
# Processing Record 43 of Set 6 | kem
# Processing Record 44 of Set 6 | birobidzhan
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | santa
# Processing Record 47 of Set 6 | roanoke rapids
# Processing Record 48 of Set 6 | bang saphan
# Processing Record 49 of Set 6 | puerto madryn
# Processing Record 50 of Set 6 | domvraina
# Processing Record 1 of Set 7 | nhamunda
# Processing Record 2 of Set 7 | requena
# Processing Record 3 of Set 7 | muros
# Processing Record 4 of Set 7 | gravdal
# Processing Record 5 of Set 7 | de aar
# Processing Record 6 of Set 7 | boguchany
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | motegi
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | oyem
# Processing Record 11 of Set 7 | aitape
# Processing Record 12 of Set 7 | ola
# Processing Record 13 of Set 7 | narasannapeta
# Processing Record 14 of Set 7 | iqaluit
# Processing Record 15 of Set 7 | sarangani
# Processing Record 16 of Set 7 | concepcion del oro
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | ylojarvi
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | newton
# Processing Record 22 of Set 7 | kirakira
# Processing Record 23 of Set 7 | itupiranga
# Processing Record 24 of Set 7 | omsukchan
# Processing Record 25 of Set 7 | port moresby
# Processing Record 26 of Set 7 | moranbah
# Processing Record 27 of Set 7 | tazovskiy
# Processing Record 28 of Set 7 | hauterive
# Processing Record 29 of Set 7 | sisimiut
# Processing Record 30 of Set 7 | ostrovnoy
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | sao filipe
# Processing Record 33 of Set 7 | rio grande
# Processing Record 34 of Set 7 | barra patuca
# Processing Record 35 of Set 7 | henties bay
# Processing Record 36 of Set 7 | tazmalt
# Processing Record 37 of Set 7 | parkes
# Processing Record 38 of Set 7 | lesnyye polyany
# Processing Record 39 of Set 7 | mareeba
# Processing Record 40 of Set 7 | shimoda
# Processing Record 41 of Set 7 | xining
# Processing Record 42 of Set 7 | angoche
# Processing Record 43 of Set 7 | caucaia
# Processing Record 44 of Set 7 | nuristan
# Processing Record 45 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | cardston
# Processing Record 48 of Set 7 | port elizabeth
# Processing Record 49 of Set 7 | qasigiannguit
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 1 of Set 8 | vaasa
# Processing Record 2 of Set 8 | port hedland
# Processing Record 3 of Set 8 | caldwell
# Processing Record 4 of Set 8 | hvide sande
# Processing Record 5 of Set 8 | clyde river
# Processing Record 6 of Set 8 | natal
# Processing Record 7 of Set 8 | hervey bay
# Processing Record 8 of Set 8 | alta floresta
# Processing Record 9 of Set 8 | menomonie
# Processing Record 10 of Set 8 | khatanga
# Processing Record 11 of Set 8 | aklavik
# Processing Record 12 of Set 8 | shirokiy
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | rabo de peixe
# Processing Record 15 of Set 8 | hare bay
# Processing Record 16 of Set 8 | mount isa
# Processing Record 17 of Set 8 | tulum
# Processing Record 18 of Set 8 | chicama
# Processing Record 19 of Set 8 | balakhninskiy
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | san vicente
# Processing Record 22 of Set 8 | kahului
# Processing Record 23 of Set 8 | mana
# Processing Record 24 of Set 8 | wawa
# Processing Record 25 of Set 8 | arman
# Processing Record 26 of Set 8 | halifax
# Processing Record 27 of Set 8 | vardo
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | gamba
# Processing Record 30 of Set 8 | weatherford
# Processing Record 31 of Set 8 | marrakesh
# Processing Record 32 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 8 | norwich
# Processing Record 34 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 35 of Set 8 | qui nhon
# Processing Record 36 of Set 8 | mus
# Processing Record 37 of Set 8 | salme
# Processing Record 38 of Set 8 | khandyga
# Processing Record 39 of Set 8 | saint-georges
# Processing Record 40 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 8 | necochea
# Processing Record 42 of Set 8 | lamu
# Processing Record 43 of Set 8 | orodara
# Processing Record 44 of Set 8 | el dorado
# Processing Record 45 of Set 8 | mayumba
# Processing Record 46 of Set 8 | izumo
# Processing Record 47 of Set 8 | richards bay
# Processing Record 48 of Set 8 | george town
# Processing Record 49 of Set 8 | berbera
# Processing Record 50 of Set 8 | mujiayingzi
# Processing Record 1 of Set 9 | la crosse
# Processing Record 2 of Set 9 | general pico
# Processing Record 3 of Set 9 | labuhan
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 9 | chingirlau
# Processing Record 7 of Set 9 | quatre cocos
# Processing Record 8 of Set 9 | agadez
# Processing Record 9 of Set 9 | janauba
# Processing Record 10 of Set 9 | alvaraes
# Processing Record 11 of Set 9 | sakakah
# Processing Record 12 of Set 9 | santander
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | kasra
# City not found. Skipping...
# Processing Record 15 of Set 9 | havelock
# Processing Record 16 of Set 9 | bandarbeyla
# Processing Record 17 of Set 9 | ningbo
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | umm lajj
# Processing Record 20 of Set 9 | benghazi
# Processing Record 21 of Set 9 | ulladulla
# Processing Record 22 of Set 9 | morondava
# Processing Record 23 of Set 9 | chapais
# Processing Record 24 of Set 9 | le port
# Processing Record 25 of Set 9 | poum
# Processing Record 26 of Set 9 | aripuana
# Processing Record 27 of Set 9 | fleet
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | cairns
# Processing Record 30 of Set 9 | mwinilunga
# Processing Record 31 of Set 9 | namibe
# Processing Record 32 of Set 9 | esperance
# Processing Record 33 of Set 9 | arica
# Processing Record 34 of Set 9 | rorvik
# Processing Record 35 of Set 9 | mococa
# Processing Record 36 of Set 9 | lao cai
# Processing Record 37 of Set 9 | santa cruz de tenerife
# Processing Record 38 of Set 9 | linhares
# Processing Record 39 of Set 9 | balabac
# Processing Record 40 of Set 9 | atar
# Processing Record 41 of Set 9 | wajima
# Processing Record 42 of Set 9 | vao
# Processing Record 43 of Set 9 | reconquista
# Processing Record 44 of Set 9 | hualmay
# Processing Record 45 of Set 9 | komsomolskiy
# Processing Record 46 of Set 9 | saint pete beach
# Processing Record 47 of Set 9 | poshekhonye
# Processing Record 48 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 49 of Set 9 | edgewater
# Processing Record 50 of Set 9 | manakara
# Processing Record 1 of Set 10 | savonlinna
# Processing Record 2 of Set 10 | port lincoln
# Processing Record 3 of Set 10 | stockton-on-tees
# Processing Record 4 of Set 10 | anchorage
# Processing Record 5 of Set 10 | tomatlan
# Processing Record 6 of Set 10 | mingshui
# Processing Record 7 of Set 10 | solnechnyy
# Processing Record 8 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 10 | upata
# Processing Record 10 of Set 10 | sainte-maxime
# Processing Record 11 of Set 10 | mitsamiouli
# Processing Record 12 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 10 | nyurba
# Processing Record 14 of Set 10 | rosarito
# Processing Record 15 of Set 10 | svetlaya
# Processing Record 16 of Set 10 | ha giang
# Processing Record 17 of Set 10 | lago da pedra
# Processing Record 18 of Set 10 | mogadishu
# Processing Record 19 of Set 10 | qeshm
# Processing Record 20 of Set 10 | bubaque
# Processing Record 21 of Set 10 | pouembout
# Processing Record 22 of Set 10 | bensonville
# Processing Record 23 of Set 10 | santa fe
# Processing Record 24 of Set 10 | moose factory
# Processing Record 25 of Set 10 | garowe
# Processing Record 26 of Set 10 | francisco sa
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | seabra
# Processing Record 29 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 30 of Set 10 | bogovarovo
# Processing Record 31 of Set 10 | fare
# Processing Record 32 of Set 10 | grindavik
# Processing Record 33 of Set 10 | cukai
# Processing Record 34 of Set 10 | college
# Processing Record 35 of Set 10 | salinopolis
# Processing Record 36 of Set 10 | bhitarwar
# Processing Record 37 of Set 10 | lahij
# Processing Record 38 of Set 10 | itaituba
# Processing Record 39 of Set 10 | hofn
# Processing Record 40 of Set 10 | katsuura
# Processing Record 41 of Set 10 | baghdad
# Processing Record 42 of Set 10 | namwala
# Processing Record 43 of Set 10 | wagga wagga
# Processing Record 44 of Set 10 | hirara
# Processing Record 45 of Set 10 | taunggyi
# Processing Record 46 of Set 10 | botngard
# Processing Record 47 of Set 10 | tuatapere
# Processing Record 48 of Set 10 | jieshi
# Processing Record 49 of Set 10 | puerto escondido
# Processing Record 50 of Set 10 | mehamn
# Processing Record 1 of Set 11 | paramonga
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | pavlohrad
# Processing Record 4 of Set 11 | shahr-e kord
# Processing Record 5 of Set 11 | shiyan
# Processing Record 6 of Set 11 | tigil
# Processing Record 7 of Set 11 | staryy nadym
# Processing Record 8 of Set 11 | inuvik
# Processing Record 9 of Set 11 | kabare
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | honiara
# Processing Record 12 of Set 11 | dongsheng
# Processing Record 13 of Set 11 | beloha
# Processing Record 14 of Set 11 | nishihara
# Processing Record 15 of Set 11 | tarbagatay
# Processing Record 16 of Set 11 | pampa
# Processing Record 17 of Set 11 | wanganui
# Processing Record 18 of Set 11 | teguldet
# Processing Record 19 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 11 | pimentel
# Processing Record 21 of Set 11 | charlestown
# Processing Record 22 of Set 11 | goba
# Processing Record 23 of Set 11 | san policarpo
# Processing Record 24 of Set 11 | gayeri
# Processing Record 25 of Set 11 | cantaura
# Processing Record 26 of Set 11 | dhidhdhoo
# Processing Record 27 of Set 11 | tonj
# Processing Record 28 of Set 11 | do rud
# City not found. Skipping...
# Processing Record 29 of Set 11 | vila do maio
# Processing Record 30 of Set 11 | makokou
# Processing Record 31 of Set 11 | camacha
# Processing Record 32 of Set 11 | bandiagara
# Processing Record 33 of Set 11 | katherine
# Processing Record 34 of Set 11 | pangai
# Processing Record 35 of Set 11 | andra
# Processing Record 36 of Set 11 | keti bandar
# Processing Record 37 of Set 11 | braslav
# City not found. Skipping...
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | nuuk
# Processing Record 40 of Set 11 | arrifes
# Processing Record 41 of Set 11 | huambo
# Processing Record 42 of Set 11 | ailigandi
# Processing Record 43 of Set 11 | dudinka
# Processing Record 44 of Set 11 | pakxan
# Processing Record 45 of Set 11 | houma
# Processing Record 46 of Set 11 | plakhtiyivka
# Processing Record 47 of Set 11 | kusti
# Processing Record 48 of Set 11 | kharitonovo
# Processing Record 49 of Set 11 | los algarrobos
# Processing Record 50 of Set 11 | kaili
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | yaan
# Processing Record 3 of Set 12 | seguin
# Processing Record 4 of Set 12 | lengshuitan
# Processing Record 5 of Set 12 | mirnyy
# Processing Record 6 of Set 12 | sistranda
# Processing Record 7 of Set 12 | havoysund
# Processing Record 8 of Set 12 | tommot
# Processing Record 9 of Set 12 | batagay
# Processing Record 10 of Set 12 | chiknayakanhalli
# Processing Record 11 of Set 12 | roma
# Processing Record 12 of Set 12 | saint-joseph
# Processing Record 13 of Set 12 | yumen
# Processing Record 14 of Set 12 | merauke
# Processing Record 15 of Set 12 | tilichiki
# Processing Record 16 of Set 12 | tuscaloosa
# Processing Record 17 of Set 12 | lysyye gory
# Processing Record 18 of Set 12 | sterling
# Processing Record 19 of Set 12 | hobyo
# Processing Record 20 of Set 12 | kruisfontein
# Processing Record 21 of Set 12 | opoczno
# Processing Record 22 of Set 12 | kamenka
# Processing Record 23 of Set 12 | tarrafal
# Processing Record 24 of Set 12 | nome
# Processing Record 25 of Set 12 | bundaberg
# Processing Record 26 of Set 12 | muroto
# Processing Record 27 of Set 12 | smithers
# Processing Record 28 of Set 12 | paita
# Processing Record 29 of Set 12 | ballina
# Processing Record 30 of Set 12 | khani
# Processing Record 31 of Set 12 | pathalgaon
# Processing Record 32 of Set 12 | machaneng
# Processing Record 33 of Set 12 | tahta
# Processing Record 34 of Set 12 | point pedro
# Processing Record 35 of Set 12 | poronaysk
# Processing Record 36 of Set 12 | drumheller
# Processing Record 37 of Set 12 | kingisepp
# Processing Record 38 of Set 12 | caraballeda
# Processing Record 39 of Set 12 | newport
# Processing Record 40 of Set 12 | levokumskoye
# Processing Record 41 of Set 12 | voh
# Processing Record 42 of Set 12 | christchurch
# Processing Record 43 of Set 12 | hailar
# Processing Record 44 of Set 12 | ha noi
# Processing Record 45 of Set 12 | alice springs
# Processing Record 46 of Set 12 | gushikawa
# Processing Record 47 of Set 12 | ekhabi
# Processing Record 48 of Set 12 | alofi
# Processing Record 49 of Set 12 | karasjok
# Processing Record 50 of Set 12 | durusu
# Processing Record 1 of Set 13 | ambovombe
# Processing Record 2 of Set 13 | ponta delgada
# Processing Record 3 of Set 13 | wewak
# Processing Record 4 of Set 13 | bijapur
# Processing Record 5 of Set 13 | creston
# Processing Record 6 of Set 13 | kibiti
# Processing Record 7 of Set 13 | sulangan
# Processing Record 8 of Set 13 | kathmandu
# Processing Record 9 of Set 13 | la quinta
# Processing Record 10 of Set 13 | wasilla
# Processing Record 11 of Set 13 | shubarshi
# Processing Record 12 of Set 13 | wenling
# Processing Record 13 of Set 13 | valvedditturai
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | las margaritas
# Processing Record 16 of Set 13 | longonjo
# Processing Record 17 of Set 13 | jiwani
# Processing Record 18 of Set 13 | zhangye
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | bilma
# Processing Record 21 of Set 13 | arlit
# Processing Record 22 of Set 13 | bonga
# Processing Record 23 of Set 13 | nanning
# Processing Record 24 of Set 13 | cerano
# Processing Record 25 of Set 13 | metro
# Processing Record 26 of Set 13 | sao felix do xingu
# Processing Record 27 of Set 13 | caxito
# Processing Record 28 of Set 13 | cuamba
# Processing Record 29 of Set 13 | baruun-urt
# Processing Record 30 of Set 13 | yar-sale
# Processing Record 31 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 13 | bilibino
# Processing Record 33 of Set 13 | chandpur
# Processing Record 34 of Set 13 | montijo
# Processing Record 35 of Set 13 | awash
# Processing Record 36 of Set 13 | dicabisagan
# Processing Record 37 of Set 13 | saratoga springs
# Processing Record 38 of Set 13 | killybegs
# Processing Record 39 of Set 13 | kunming
# Processing Record 40 of Set 13 | karibib
# Processing Record 41 of Set 13 | parkersburg
# Processing Record 42 of Set 13 | guisijan
# Processing Record 43 of Set 13 | ladario
# Processing Record 44 of Set 13 | aromashevo
# Processing Record 45 of Set 13 | kardailovo
# Processing Record 46 of Set 13 | platonovka
# Processing Record 47 of Set 13 | kabalo
# Processing Record 48 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 49 of Set 13 | boa vista
# Processing Record 50 of Set 13 | altar
# Processing Record 1 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 14 | ouricuri
# Processing Record 3 of Set 14 | tenenkou
# Processing Record 4 of Set 14 | lulea
# Processing Record 5 of Set 14 | synya
# Processing Record 6 of Set 14 | novyy urengoy
# Processing Record 7 of Set 14 | kawalu
# Processing Record 8 of Set 14 | bara
# Processing Record 9 of Set 14 | challapata
# Processing Record 10 of Set 14 | sur
# Processing Record 11 of Set 14 | otavi
# Processing Record 12 of Set 14 | westport
# Processing Record 13 of Set 14 | amahai
# Processing Record 14 of Set 14 | stokmarknes
# Processing Record 15 of Set 14 | sitka
# Processing Record 16 of Set 14 | mahon
# Processing Record 17 of Set 14 | las palmas
# Processing Record 18 of Set 14 | tabou
# Processing Record 19 of Set 14 | kushima
# Processing Record 20 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 14 | pemangkat
# Processing Record 22 of Set 14 | ancud
# Processing Record 23 of Set 14 | banon
# Processing Record 24 of Set 14 | konevo
# Processing Record 25 of Set 14 | jalu
# Processing Record 26 of Set 14 | miandoab
# Processing Record 27 of Set 14 | bazarnyy syzgan
# Processing Record 28 of Set 14 | manzanillo
# Processing Record 29 of Set 14 | vrangel
# Processing Record 30 of Set 14 | yellapur
# Processing Record 31 of Set 14 | charlottesville
# Processing Record 32 of Set 14 | kamaishi
# Processing Record 33 of Set 14 | haines junction
# Processing Record 34 of Set 14 | benavente
# Processing Record 35 of Set 14 | maamba
# Processing Record 36 of Set 14 | bom jesus
# Processing Record 37 of Set 14 | udachnyy
# Processing Record 38 of Set 14 | sokoni
# Processing Record 39 of Set 14 | puerto leguizamo
# Processing Record 40 of Set 14 | mao
# Processing Record 41 of Set 14 | belogorsk
# Processing Record 42 of Set 14 | saint-augustin
# Processing Record 43 of Set 14 | greymouth
# Processing Record 44 of Set 14 | majene
# Processing Record 45 of Set 14 | kaka
# Processing Record 46 of Set 14 | wuwei
# Processing Record 47 of Set 14 | sao mateus
# Processing Record 48 of Set 14 | weyburn
# Processing Record 49 of Set 14 | juruti
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | amazar
# Processing Record 2 of Set 15 | port hueneme
# Processing Record 3 of Set 15 | surt
# Processing Record 4 of Set 15 | uyuni
# Processing Record 5 of Set 15 | hamada
# Processing Record 6 of Set 15 | bulgan
# Processing Record 7 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 15 | umm qays
# Processing Record 9 of Set 15 | danane
# Processing Record 10 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 15 | port hardy
# Processing Record 12 of Set 15 | bouar
# Processing Record 13 of Set 15 | coracora
# Processing Record 14 of Set 15 | asosa
# Processing Record 15 of Set 15 | candolim
# Processing Record 16 of Set 15 | carutapera
# Processing Record 17 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 18 of Set 15 | kingston
# Processing Record 19 of Set 15 | ambon
# Processing Record 20 of Set 15 | qaqortoq
# Processing Record 21 of Set 15 | udimskiy
# Processing Record 22 of Set 15 | ayr
# Processing Record 23 of Set 15 | bukama
# Processing Record 24 of Set 15 | asau
# Processing Record 25 of Set 15 | sal rei
# Processing Record 26 of Set 15 | evensk
# Processing Record 27 of Set 15 | wanning
# Processing Record 28 of Set 15 | taybad
# Processing Record 29 of Set 15 | sao joao de pirabas
# Processing Record 30 of Set 15 | morant bay
# Processing Record 31 of Set 15 | malnas
# Processing Record 32 of Set 15 | raga
# Processing Record 33 of Set 15 | guilin
# Processing Record 34 of Set 15 | wolgast
# Processing Record 35 of Set 15 | salmon arm
# Processing Record 36 of Set 15 | sri aman
# Processing Record 37 of Set 15 | dalvik
# Processing Record 38 of Set 15 | santa cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Ushuaia -54.8000  -68.3000     38.86          few clouds        87
# 1    Saint-Pierre -21.3393   55.4781     73.29           clear sky        72
# 2  Severo-Kurilsk  50.6789  156.1250     36.23       broken clouds        85
# 3           Totma  59.9747   42.7642     26.56       broken clouds        96
# 4   Copperas Cove  31.1241  -97.9031     80.80       broken clouds        61
#
#    Cloudiness  Wind Speed Country
# 0          20        9.22      AR
# 1           0        5.75      RE
# 2          83        8.43      RU
# 3          83        3.58      RU
# 4          75       11.50      US

# %%
weather_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
weather_data_df = weather_data_df[['City','Country','Lat', 'Lng', 'Max Temp','Humidity',
       'Cloudiness', 'Wind Speed', 'Current Description']]

# %%
weather_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     38.86        87          20
# 1    Saint-Pierre      RE -21.3393   55.4781     73.29        72           0
# 2  Severo-Kurilsk      RU  50.6789  156.1250     36.23        85          83
# 3           Totma      RU  59.9747   42.7642     26.56        96          83
# 4   Copperas Cove      US  31.1241  -97.9031     80.80        61          75
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        5.75           clear sky
# 2        8.43       broken clouds
# 3        3.58       broken clouds
# 4       11.50       broken clouds

# %%
output_data_file = "../weather_database/weatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
